# %% [markdown]
# # 📓 Brincando com um LLM (DistilGPT-2)
#
# ## 🎯 Objetivo
# Neste notebook, vamos explorar um **LLM menor** chamado **DistilGPT-2**, que é uma versão compacta do GPT-2.
# Vamos usá-lo para **geração de texto**, completando frases e respondendo perguntas simples.

# %% [markdown]
# ## 1️⃣ Instalar e importar dependências

# %%
# !pip install transformers torch --quiet

# %%
from transformers import pipeline, set_seed

# %% [markdown]
# ## 2️⃣ Carregar o modelo DistilGPT-2

# %%
# Carregar o pipeline de geração de texto
generator = pipeline("text-generation", model="distilgpt2")

# Definir semente para resultados reprodutíveis
set_seed(42)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %% [markdown]
# ## 3️⃣ Primeira geração de texto

# %%
prompt = "Artificial intelligence is transforming the world because"
result = generator(prompt, max_length=50, num_return_sequences=1)

print(result[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# A galinha bota ovo porque (succeeded) and the egg of a porque. As is most commonly observed in the wild, it is also common to find the eggs in the wild. The eggs of the porque are small and are not as large as the eggs used to make them.

# %% [markdown]
# ## 4️⃣ Gerando múltiplas variações

# %%
prompt = "The future of deep learning is"
results = generator(prompt, max_length=60, num_return_sequences=3, do_sample=True, top_k=50)

for i, r in enumerate(results):
    print(f"\n🔹 Geração {i+1}:\n{r['generated_text']}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 🔹 Geração 1:
# The future of deep learning is in the eye of the beholder. Deep learning is a challenge for researchers to understand how to build deep learning applications for humans.
#
#
#
#
#
#
# The Stanford-based company Sivs, a new company, will launch a new series of neural networks to solve problems in the deep learning field and to improve the process of learning. The company will also create a new class of neural networks to solve problems in the deep learning field, and to improve the process of learning.
#
#
# ...

# %% [markdown]
# ## 5️⃣ Simulando Perguntas e Respostas simples

# %%
questions = [
    "Q: What is deep learning?\nA:",
    "Q: Who created the theory of relativity?\nA:",
    "Q: What is the capital of Brazil?\nA:"
]

for q in questions:
    answer = generator(q, max_length=40, num_return_sequences=1)
    print(f"\n{answer[0]['generated_text']}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Q: What is deep learning?
# ...

# %% [markdown]
# ## 6️⃣ Conclusão
# - Vimos como **usar DistilGPT-2** para geração de texto.
# - Ele consegue **completar frases** e até responder perguntas simples, mas não é tão poderoso quanto os LLMs gigantes.
# - Serve como uma ótima introdução prática para brincar com **modelos de linguagem**!
